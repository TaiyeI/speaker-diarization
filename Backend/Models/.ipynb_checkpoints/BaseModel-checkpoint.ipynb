# %%
# !pip install tensorflow
# !pip install tensorflow-gpu
# !pip install nvidia-cudnn-cu12
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nvidia-cudnn-cu12 in /home/tymstr/.local/lib/python3.12/site-packages (9.8.0.87)
# Requirement already satisfied: nvidia-cublas-cu12 in /home/tymstr/.local/lib/python3.12/site-packages (from nvidia-cudnn-cu12) (12.4.5.8)

# %%
import os
import time
import math

import cv2
import numpy as np

# %% [markdown]
# Dataset:
# - https://spandh.dcs.shef.ac.uk//gridcorpus/
#
# Medium Article:
# - https://medium.com/towards-data-science/designing-your-neural-networks-a5e4617027ed

# %% [markdown]
# Inputs:
# - [ ] Organise Dataset of choice in files
#     - Silentframes - format: {filename}_sil_x.mpg
#     - OneWordframes -format: {filename}_word_x.mpg x represents the line number in the file
#     - Multiword frames?? - {stiched from one word frames using x value to verify continuity}
# - [ ] Generate consistent script to iterate through files
# - [ ] Catogerise files into relevant categories (speaking frames: non-speaking frames)
# - [ ] Remove excess pixels and standardise image size
# - [ ] Numpyify and injest from model

# %% [markdown]
# Dataset of Choice is LipNet
# Key folders:
# S1 - contains video audio footage
# Alignments/S1 - contains aligned audio transcriptions

# %%
# LIPNET_S1_DIR = "/media/tymstr/Expansion/DiarizeDatabase/lipnetdata/s1"
# LIPNET_ALIGNMENTS_DIR = "/media/tymstr/Expansion/DiarizeDatabase/lipnetdata/alignments/s1"

# GRID_S1_DIR = "/media/tymstr/Expansion/DiarizeDatabase/gridcorpusdata/s1"
# GRID_ALIGNMENTS_DIR = "/media/tymstr/Expansion/DiarizeDatabase/gridcorpusdata/align"

FULL_GRID_DIR = "/media/tymstr/Expansion/DiarizeDatabase/gridcorpusdata"

TEST_GRID_DIR = "/media/tymstr/Expansion/DiarizeDatabase/gridcorpusdatatest"

# TEST_ALIGNMENT_DIR = "/media/tymstr/Expansion/DiarizeDatabase/testmodeldata/align"
# TEST_S1_DIR = "/media/tymstr/Expansion/DiarizeDatabase/testmodeldata/S1"

# VALIDATION_ALIGNMENT_DIR = "/media/tymstr/Expansion/DiarizeDatabase/validationdata/align"
# VALIDATION_S1_DIR = "/media/tymstr/Expansion/DiarizeDatabase/validationdata/S2"

def getAlignFiles(ALIGNMENTS_DIR: str):
    files = []
    for file in os.listdir(ALIGNMENTS_DIR):
        files.append(file)
    return files

def getVideoFiles(S1_DIR: str):
    files = []
    for file in os.listdir(S1_DIR):
        files.append(file)

    return files

def deconstructAlign(dir, filename):
    alignment_array = []
    y = dir + "/" + filename
    with open(y, 'r') as file:
        for line in file:
            alignment_array.append(line.strip('\n').split(" "))
    
    return alignment_array

def deconstructS1(dir, i):
    x = getVideoFiles(dir)[i]
    y = dir + "/" + x
    video = cv2.VideoCapture(y)
    num_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))

    success = True
    count = 0
    while success:
        success, img = video.read()
        if success==False:
            break
        count += 1
        
 
def calculateClips(filename, alignment_array, vid_folder):
    # alignment_array = deconstructAlign(GRID_ALIGNMENTS_DIR,0)
    # filename  = getAlignFiles(GRID_ALIGNMENTS_DIR)[0]
    clips = []
    for alignment in alignment_array:
        start, end, word = alignment
        start_frame = math.ceil(int(start)*0.001)
        end_frame = math.ceil(int(end)*0.001)
        # print("Start Frame:", start_frame, "End Frame:", end_frame, "Word:", word)

        clips.append([filename, start_frame, end_frame, word, vid_folder])

    return clips
# print(deconstructAlign(GRID_ALIGNMENTS_DIR,0))

# deconstructS1(GRID_S1_DIR,0)
def allClips(folder): 
    all_clips = []#hold all clips in form [filename, start_frame, end_frame, word]
    #for all files in all folders
    for subject in os.listdir(folder):
        try:
            align_folder = folder + "/" + subject + "/align"
            for filename in getAlignFiles(align_folder):
                alignment_array = deconstructAlign(align_folder,filename)
                vid_folder = folder + "/" + subject + "/" + subject
                video_clips = calculateClips(filename, alignment_array, vid_folder)#replace folder with videopath or alignpath
                for clip in video_clips:
                    all_clips.append(clip)
        except:
            pass

    return np.array(all_clips)

# # x = allClips(FULL_GRID_DIR + "/S1/align")
# for subject in os.listdir(FULL_GRID_DIR):
#     try:
#         video_list = os.listdir(FULL_GRID_DIR + "/" + subject + "/" + subject)
#         align_list = os.listdir(FULL_GRID_DIR + "/" + subject + "/align")
#         print(subject, align_list)
#     except:
#         print("non existant", subject)
#Given a file, 0, 23000
#return frames?

# print((allClips(FULL_GRID_DIR)))

# To determine the size of the input find the large amount of time a person is saying a single word (exclude silence?)
# Lipnet Organise Folder for classified data

# %% [markdown]
# Calculate Frame to alignment
#
# Numofframes = cv2.CAP_PROP_FRAME_COUNT() //
# length of video (seconds) = ffmpeg -i bbaf2n.mpg 2>&1 | grep "Duration"
#
#
# 1.
# Khz to Time
# X khz / 25000 = time (seconds)
# 2.
# Time to Frames
# Time / Clip time = frame / num of frames
# 3.def:
# khz to frames relationship
# ((X khz / 25000) / Clip time) x num of frames =~ frame
#
# Given a .align for each line in .align
# startframe, endframe = khztoframes(startvalue), khztoframes(endvalue)
# if word == sil:
#     add to non talking dataset
# else:
#     add to talking dataset

# %%
import tensorflow as tf
import mediapipe as mp
# Out:
# 2025-03-14 19:57:51.757473: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1741982271.770015  257726 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1741982271.773838  257726 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1741982271.784291  257726 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1741982271.784309  257726 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1741982271.784311  257726 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1741982271.784312  257726 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-14 19:57:51.787572: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def exampleFrame():
    dir = GRID_S1_DIR
    x = getVideoFiles(dir)[0]
    y = dir + "/" + x
    video = cv2.VideoCapture(y)
    video.set(cv2.CAP_PROP_POS_FRAMES, 0)
    res, frame = video.read()
    
    return frame

# %%
MOUTH_LANDMARKS = [0, 267, 269, 270, 409, 306, 375, 321, 405, 314, 17, 84, 181, 91, 146, 61, 185, 40, 39,
                                37]

mpDraw = mp.solutions.drawing_utils
mpFaceMesh = mp.solutions.face_mesh
faceMesh = mpFaceMesh.FaceMesh(max_num_faces=2)
drawSpec = mpDraw.DrawingSpec(thickness=1, circle_radius=1)

def findMouth(img, output):
    points = []
    dict = {}
    try:
        results = faceMesh.process(img)
        if results.multi_face_landmarks:
            for faceLms in results.multi_face_landmarks:
                # mpDraw.draw_landmarks(img, faceLms, mpFaceMesh.FACEMESH_CONTOURS, drawSpec, drawSpec)
                for id,lm in enumerate(faceLms.landmark):
                    image_height, image_width, image_channels = img.shape
                    x,y = int(lm.x*image_width), int(lm.y*image_height)
                    if id in MOUTH_LANDMARKS:
                        points.append((x,y))
                        dict[id] = (x,y)
    except:
        points.append((41,61))
    if output == "points":            
        return points
    else:
        return dict
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741982274.122310  257726 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1741982274.146991  257845 gl_context.cc:369] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 550.120), renderer: NVIDIA GeForce RTX 4070/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %%
# x = findMouth(exampleFrame(), "points")
# print(x)
# y, z = x[0]
# print(y, z)
# Out:
# W0000 00:00:1741982274.151490  257838 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
# Frames from video returns a numpy array

#large shufflable list
# list = [[filename, word, startframe, endframe], ...]  (This list will be defined/shuffled in Frame Generator)

#exampleframe = cv2.imread(image_path)

def formatFrames(frame, output_size):
    try:
        mouthpoints = findMouth(frame, "points")
        x,y = mouthpoints[0]
        # print(type(frame))
        #Resize image around the mouth
        new_frame = frame[y-40:y+60,x-50:x+50,:]
        
        # cv2.waitKey(0)
        # cv2.destroyAllWindows()
        #Convert into an acceptable format
    except:
        new_frame = frame[0:100, 0:100]


    new_frame = tf.image.convert_image_dtype(new_frame, tf.float32)
    new_frame = tf.image.resize_with_pad(new_frame, *output_size)
    return new_frame


# formatFrames(exampleFrame(), (100, 100))
# Out:
# W0000 00:00:1741982274.161216  257844 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.

# %%
#large shufflable list
# list = [[filename, word, startframe, endframe], ...]  (This list will be defined/shuffled in Frame Generator)
#Given a videopath
# calculateClips(video_path)
#AllClips(GRID_ALIGNMENTS_DIR)

import random
import numpy as np


def framesFromVideo(video_path, clip_name, clip_start, clip_end, clip_word):
    
    result = []
    full_path = video_path + "/" + clip_name
    
    # clip_end = int(clip_end)
    # clip_start - int(clip_start)
    video = cv2.VideoCapture(full_path)
    # print(full_path)

    # print(type(video))
    if int(clip_end) >= 11:
        for i in range(11, 1, -1):
            video.set(cv2.CAP_PROP_POS_FRAMES, int(clip_end)-i)
            res, frame = video.read()
            if not res:
                # print("clip end:", clip_end)
                # print("clip start:", clip_start)
                # print("i:", i)
                #This is being invoked quite often figure out why
                return 0

            result.append(formatFrames(frame, (100,100)))
    else:
        clip_length = min(int(clip_end) - int(clip_start), 10)
        
        # print("Clip length:" , clip_length)
        for i in range(clip_length):
            video.set(cv2.CAP_PROP_POS_FRAMES, int(clip_start)+i)
            res, frame = video.read()
            if not res:
                print("I've pissed me self in the else statement sir")
                return 0
            result.append(formatFrames(frame, (100,100)))
        remaining_frames = [result[-1]] * (10-len(result))
        result += remaining_frames
        # print("Result length:" , len(result))
        # print("Remaining Frames length:" , len(remaining_frames))

    #return  a numpy array of the frames
    video.release()
    # if len(result) == 0:
    #     return np.array([])
    

    result = np.array(result)[..., [2,1,0]]

    return result


def clipsOrganised(path):
    ALL_CLIPS = allClips(path)
    talking_clips = []
    non_talking_clips = []
    unshuffled_clips_array = []
    for i in range(len(ALL_CLIPS)):
        clip_name, clips_start, clip_end, clip_word, video_folder = ALL_CLIPS[i]
        if clip_word != "sil":
            label = 1
            talking_clips.append(ALL_CLIPS[i]) 
        else:
            label = 0
            non_talking_clips.append(ALL_CLIPS[i])


    num_ntc = len(non_talking_clips)
    num_tc = len(talking_clips)

    if num_ntc < num_tc:
        unshuffled_clips_array.append(non_talking_clips[num_ntc-50:])
        unshuffled_clips_array.append(talking_clips[num_ntc-50:])
    else:
        unshuffled_clips_array.append(non_talking_clips[num_tc-50:])
        unshuffled_clips_array.append(talking_clips[num_tc-50:])

    return talking_clips + non_talking_clips

class FrameGenerator():
    def __init__(self, dataset_path, training=False):
        # self.align_path = align_path
        # self.video_path = video_path
        self.dataset_path = dataset_path
        self.training = training
    pass


    def __call__(self):
        ALL_CLIPS = clipsOrganised(self.dataset_path)

    
        if self.training:
            np.random.shuffle(ALL_CLIPS)

        for clip_name, clips_start, clip_end, clip_word, video_path in ALL_CLIPS:
            video_clip_name = clip_name.split(".")[0]+".mpg"
            video_frames = framesFromVideo(video_path, video_clip_name, clips_start, clip_end, clip_word)

            try:
                if len(video_frames) == 0:
                    continue
            except:
                continue
            if clip_word != "sil":
                label = 1
            else:
                label = 0

            # print(video_clip_name, len(video_frames), label)
            yield video_frames, label

        #returns a set of frames with their associated label

# %%
fg = FrameGenerator(FULL_GRID_DIR, True)

frames, label = next(fg())

print(f"Shape: {frames.shape}")
print(f"Label: {label}")
# Out:
# W0000 00:00:1741982274.521894  257833 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# I0000 00:00:1741982274.631123  257726 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 8355 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070, pci bus id: 0000:01:00.0, compute capability: 8.9
# Shape: (10, 100, 100, 3)
# Label: 1

# %%
output_signature = (tf.TensorSpec(shape = (None,None, None,3), dtype = tf.float32),
                    tf.TensorSpec(shape = (), dtype = tf.int16))
train_ds = tf.data.Dataset.from_generator(FrameGenerator(FULL_GRID_DIR, True),
                                          output_signature = output_signature)
val_ds = tf.data.Dataset.from_generator(FrameGenerator(FULL_GRID_DIR, True),
                                          output_signature = output_signature)
test_ds = tf.data.Dataset.from_generator(FrameGenerator(FULL_GRID_DIR, True),
                                          output_signature = output_signature)

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.shuffle(1000).cache().prefetch(buffer_size = AUTOTUNE)
val_ds = val_ds.shuffle(1000).cache().prefetch(buffer_size = AUTOTUNE)
test_ds = test_ds.shuffle(1000).cache().prefetch(buffer_size = AUTOTUNE)

# %%
train_ds = train_ds.batch(2)
val_ds = val_ds.batch(2)
test_ds = test_ds.batch(2)

# %%
# train_frames, train_labels = next(iter(train_ds),)
  
# val_frames, val_labels = next(iter(val_ds))clip_end

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Conv3D, LSTM, Dense, Dropout, Bidirectional, MaxPool3D, Activation, Reshape, SpatialDropout3D, BatchNormalization, TimeDistributed, Flatten
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler

# %% [markdown]
# ### Model 2

# %%
# model2 = tf.keras.Sequential()
# model2.add(Conv3D(128, 3, input_shape=(3,100,100,3), padding='same'))
# model2.add(Activation('relu'))
# model2.add(MaxPool3D((1,2,2)))clip_length

# model2.add(Conv3D(256, 3, padding='same'))
# model2.add(Activation('relu'))
# model2.add(MaxPool3D((1,2,2)))

# # model2.add(Conv3D(75, 3, padding='same'))
# # model2.add(Activation('relu'))
# # model2.add(MaxPool3D((1,2,2)))

# model2.add(TimeDistributed(Flatten()))

# model2.add(Bidirectional(LSTM(128, kernel_initializer='Orthogonal', return_sequences=True)))
# model2.add(Dropout(.5))

# model2.add(Bidirectional(LSTM(128, kernel_initializer='Orthogonal', return_sequences=True)))
# model2.add(Dropout(.5))

# model2.add(Dense(1, kernel_initializer='he_normal', activation='sigmoid'))

# %%
# model2.compile(optimizer = 'adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
#               metrics=['accuracy'])

# model2.fit(train_ds, 
#           epochs = 10,
#           validation_data = val_ds,
#           callbacks = tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'))

# %% [markdown]
# ### Model 1

# %%
# net = tf.keras.applications.EfficientNetB0(include_top = False)
# net.trainable = False

# model = tf.keras.Sequential([
#     tf.keras.layers.Rescaling(scale=255),
#     tf.keras.layers.TimeDistributed(net),
#     tf.keras.layers.Dense(10),
#     tf.keras.layers.GlobalAveragePooling3D()
# ])

# model.compile(optimizer = 'adam',
#               loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = True),
#               metrics=['accuracy'])

# model.fit(train_ds, 
#           epochs = 10,
#           validation_data = val_ds,
#           callbacks = tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'))

# %% [markdown]
# ### Model 3

# %%
from tensorflow.keras import layers, models

# model3 = models.Sequential([
#     layers.ConvLSTM2D(filters=16, kernel_size=(3, 3), padding='same', return_sequences=True, input_shape=(10, 100, 100, 3)),
#     layers.BatchNormalization(),
#     layers.ConvLSTM2D(filters=32, kernel_size=(3, 3), padding='same', return_sequences=True),
#     layers.BatchNormalization(),
#     layers.ConvLSTM2D(filters=32, kernel_size=(3, 3), padding='same', return_sequences=False),
#     layers.BatchNormalization(),
#     layers.Flatten(),
#     # layers.Dense(128, activation='relu'),
#     layers.Dense(64, activation='relu'),
#     layers.Dense(1, activation='sigmoid')
# ])

# model3.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# model3.fit(train_ds, 
#           epochs = 10,
#           validation_data = val_ds,
#           callbacks = tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'))

# %% [markdown]
# ### Model 4

# %%
input_shape = (10, 100, 100, 3)

model4 = models.Sequential([
    # Input Layer
    layers.Input(shape=input_shape),

    # (2+1)D Conv Block 1
    layers.Conv3D(32, kernel_size=(1, 3, 3), padding='same', activation='relu'),
    layers.Conv3D(32, kernel_size=(3, 1, 1), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling3D(pool_size=(1, 2, 2)),

    # (2+1)D Conv Block 2
    layers.Conv3D(64, kernel_size=(1, 3, 3), padding='same', activation='relu'),
    layers.Conv3D(64, kernel_size=(3, 1, 1), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling3D(pool_size=(2, 2, 2)),

    # (2+1)D Conv Block 3
    layers.Conv3D(128, kernel_size=(1, 3, 3), padding='same', activation='relu'),
    layers.Conv3D(128, kernel_size=(3, 1, 1), padding='same', activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling3D(pool_size=(2, 2, 2)),

    # Global Feature Aggregation
    layers.GlobalAveragePooling3D(),
    layers.Dropout(0.5),

    # Fully Connected Layer
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.3),

    # Output Layer (Binary Classification)
    layers.Dense(1, activation='sigmoid')  # Change from softmax to sigmoid
])

# Compile Model
model4.compile(optimizer='adam',
              loss=tf.keras.losses.BinaryCrossentropy(),  # Change loss function
              metrics=['accuracy'])

# Model Summary
history = model4.fit(train_ds, 
          epochs = 9,
          validation_data = val_ds,
          callbacks = tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'))
# Out:
# Epoch 1/9
# 2025-03-14 19:58:07.792990: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 91 of 1000
# 2025-03-14 19:58:17.825723: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 188 of 1000
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# 2025-03-14 19:58:37.820252: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 380 of 1000
# 2025-03-14 19:58:57.826388: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 557 of 1000
# 2025-03-14 19:59:07.850367: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 642 of 1000
# I've pissed me self in the else statement sir
# 2025-03-14 19:59:27.849891: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 816 of 1000
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# 2025-03-14 19:59:47.780512: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:6: Filling up shuffle buffer (this may take a while): 988 of 1000
# 2025-03-14 19:59:49.058546: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1741982389.167496  257882 service.cc:152] XLA service 0x7187b4036a20 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1741982389.167510  257882 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070, Compute Capability 8.9
# 2025-03-14 19:59:49.231537: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1741982389.723540  257882 cuda_dnn.cc:529] Loaded cuDNN version 90800
#       1/Unknown 118s 118s/step - accuracy: 1.0000 - loss: 0.2534
# I0000 00:00:1741982393.579202  257882 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#     212/Unknown 166s 228ms/step - accuracy: 0.6342 - loss: 0.7085I've pissed me self in the else statement sir
#     321/Unknown 192s 231ms/step - accuracy: 0.6483 - loss: 0.6947I've pissed me self in the else statement sir
#     464/Unknown 225s 232ms/step - accuracy: 0.6644 - loss: 0.6791I've pissed me self in the else statement sir
#     563/Unknown 249s 233ms/step - accuracy: 0.6717 - loss: 0.6711I've pissed me self in the else statement sir
#     596/Unknown 256s 233ms/step - accuracy: 0.6741 - loss: 0.6683I've pissed me self in the else statement sir
#     752/Unknown 292s 232ms/step - accuracy: 0.6830 - loss: 0.6578I've pissed me self in the else statement sir
#     834/Unknown 311s 233ms/step - accuracy: 0.6873 - loss: 0.6526I've pissed me self in the else statement sir
#     967/Unknown 342s 232ms/step - accuracy: 0.6931 - loss: 0.6457I've pissed me self in the else statement sir
#    1087/Unknown 370s 232ms/step - accuracy: 0.6976 - loss: 0.6406I've pissed me self in the else statement sir
#    1153/Unknown 385s 232ms/step - accuracy: 0.7000 - loss: 0.6376I've pissed me self in the else statement sir
#    1259/Unknown 409s 232ms/step - accuracy: 0.7032 - loss: 0.6334I've pissed me self in the else statement sir
#    1349/Unknown 428s 230ms/step - accuracy: 0.7056 - loss: 0.6299I've pissed me self in the else statement sir
#    1440/Unknown 447s 229ms/step - accuracy: 0.7077 - loss: 0.6264I've pissed me self in the else statement sir
#    1499/Unknown 460s 229ms/step - accuracy: 0.7090 - loss: 0.6242I've pissed me self in the else statement sir
#    1606/Unknown 483s 228ms/step - accuracy: 0.7111 - loss: 0.6202I've pissed me self in the else statement sir
#    1746/Unknown 513s 226ms/step - accuracy: 0.7138 - loss: 0.6150I've pissed me self in the else statement sir
#    1765/Unknown 517s 226ms/step - accuracy: 0.7141 - loss: 0.6143I've pissed me self in the else statement sir
#    1863/Unknown 538s 226ms/step - accuracy: 0.7158 - loss: 0.6107I've pissed me self in the else statement sir
#    1908/Unknown 547s 225ms/step - accuracy: 0.7165 - loss: 0.6091I've pissed me self in the else statement sir
#    2175/Unknown 604s 224ms/step - accuracy: 0.7204 - loss: 0.5998I've pissed me self in the else statement sir
#    2305/Unknown 632s 223ms/step - accuracy: 0.7223 - loss: 0.5951I've pissed me self in the else statement sir
#    2398/Unknown 652s 223ms/step - accuracy: 0.7237 - loss: 0.5918I've pissed me self in the else statement sir
#    2696/Unknown 718s 223ms/step - accuracy: 0.7280 - loss: 0.5817I've pissed me self in the else statement sir
#    2697/Unknown 719s 223ms/step - accuracy: 0.7280 - loss: 0.5816I've pissed me self in the else statement sir
#    2891/Unknown 762s 223ms/step - accuracy: 0.7307 - loss: 0.5755I've pissed me self in the else statement sir
#    2903/Unknown 765s 223ms/step - accuracy: 0.7308 - loss: 0.5751I've pissed me self in the else statement sir
#    3077/Unknown 803s 223ms/step - accuracy: 0.7332 - loss: 0.5698I've pissed me self in the else statement sir
#    3140/Unknown 817s 223ms/step - accuracy: 0.7341 - loss: 0.5680I've pissed me self in the else statement sir
#    3142/Unknown 817s 223ms/step - accuracy: 0.7341 - loss: 0.5680I've pissed me self in the else statement sir
#    3495/Unknown 897s 223ms/step - accuracy: 0.7385 - loss: 0.5583I've pissed me self in the else statement sir
#    3555/Unknown 911s 223ms/step - accuracy: 0.7393 - loss: 0.5567I've pissed me self in the else statement sir
#    3600/Unknown 921s 223ms/step - accuracy: 0.7398 - loss: 0.5555I've pissed me self in the else statement sir
#    3727/Unknown 949s 223ms/step - accuracy: 0.7414 - loss: 0.5522I've pissed me self in the else statement sir
#    3812/Unknown 967s 223ms/step - accuracy: 0.7424 - loss: 0.5501I've pissed me self in the else statement sir
#    3832/Unknown 972s 223ms/step - accuracy: 0.7427 - loss: 0.5496I've pissed me self in the else statement sir
#    3850/Unknown 976s 223ms/step - accuracy: 0.7429 - loss: 0.5491I've pissed me self in the else statement sir
#    3893/Unknown 985s 223ms/step - accuracy: 0.7434 - loss: 0.5481I've pissed me self in the else statement sir
#    3987/Unknown 1007s 223ms/step - accuracy: 0.7445 - loss: 0.5458I've pissed me self in the else statement sir
#    4067/Unknown 1024s 223ms/step - accuracy: 0.7455 - loss: 0.5439I've pissed me self in the else statement sir
#    4070/Unknown 1025s 223ms/step - accuracy: 0.7455 - loss: 0.5438I've pissed me self in the else statement sir
#    4078/Unknown 1027s 223ms/step - accuracy: 0.7456 - loss: 0.5436I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
#    4212/Unknown 1056s 223ms/step - accuracy: 0.7471 - loss: 0.5405I've pissed me self in the else statement sir
#    4290/Unknown 1073s 223ms/step - accuracy: 0.7479 - loss: 0.5388I've pissed me self in the else statement sir
#    4297/Unknown 1075s 223ms/step - accuracy: 0.7480 - loss: 0.5386I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
#    4328/Unknown 1081s 223ms/step - accuracy: 0.7483 - loss: 0.5380I've pissed me self in the else statement sir
#    4341/Unknown 1084s 223ms/step - accuracy: 0.7485 - loss: 0.5377I've pissed me self in the else statement sir
#    4371/Unknown 1091s 223ms/step - accuracy: 0.7488 - loss: 0.5370I've pissed me self in the else statement sir
#    4749/Unknown 1174s 223ms/step - accuracy: 0.7528 - loss: 0.5291I've pissed me self in the else statement sir
#    4802/Unknown 1186s 223ms/step - accuracy: 0.7533 - loss: 0.5280I've pissed me self in the else statement sir
#    4989/Unknown 1227s 223ms/step - accuracy: 0.7553 - loss: 0.5243I've pissed me self in the else statement sir
#    5125/Unknown 1258s 222ms/step - accuracy: 0.7567 - loss: 0.5216I've pissed me self in the else statement sir
#    5265/Unknown 1289s 222ms/step - accuracy: 0.7582 - loss: 0.5189I've pissed me self in the else statement sir
#    5363/Unknown 1310s 222ms/step - accuracy: 0.7592 - loss: 0.5170I've pissed me self in the else statement sir
#    5384/Unknown 1315s 222ms/step - accuracy: 0.7594 - loss: 0.5166
# [mpeg1video @ 0x71854003a400] ac-tex damaged at 22 17
# [mpeg1video @ 0x71854003a400] Warning MVs not available
# [mpeg1video @ 0x71854003a400] ac-tex damaged at 22 17
# [mpeg1video @ 0x71854003a400] Warning MVs not available
# [mpeg1video @ 0x71854003a400] ac-tex damaged at 22 17
# [mpeg1video @ 0x71854003a400] Warning MVs not available
# [mpeg1video @ 0x71854003a400] ac-tex damaged at 22 17
# [mpeg1video @ 0x71854003a400] Warning MVs not available
# [mpeg1video @ 0x71854003a400] ac-tex damaged at 22 17
# [mpeg1video @ 0x71854003a400] Warning MVs not available
# [mpeg1video @ 0x71854003a400] ac-tex damaged at 22 17
# [mpeg1video @ 0x71854003a400] Warning MVs not available
# [mpeg1video @ 0x71854003a400] ac-tex damaged at 22 17
# [mpeg1video @ 0x71854003a400] Warning MVs not available
#    5437/Unknown 1327s 222ms/step - accuracy: 0.7599 - loss: 0.5156I've pissed me self in the else statement sir
#    5543/Unknown 1351s 223ms/step - accuracy: 0.7610 - loss: 0.5137I've pissed me self in the else statement sir
#    5662/Unknown 1377s 223ms/step - accuracy: 0.7621 - loss: 0.5115I've pissed me self in the else statement sir
#    5812/Unknown 1411s 223ms/step - accuracy: 0.7636 - loss: 0.5088I've pissed me self in the else statement sir
#    5817/Unknown 1412s 223ms/step - accuracy: 0.7636 - loss: 0.5087I've pissed me self in the else statement sir
#    5906/Unknown 1432s 223ms/step - accuracy: 0.7645 - loss: 0.5072I've pissed me self in the else statement sir
#    6333/Unknown 1526s 222ms/step - accuracy: 0.7683 - loss: 0.5000I've pissed me self in the else statement sir
#    6338/Unknown 1527s 222ms/step - accuracy: 0.7684 - loss: 0.4999I've pissed me self in the else statement sir
#    6485/Unknown 1558s 222ms/step - accuracy: 0.7696 - loss: 0.4976I've pissed me self in the else statement sir
#    6538/Unknown 1569s 222ms/step - accuracy: 0.7701 - loss: 0.4968I've pissed me self in the else statement sir
#    6594/Unknown 1581s 222ms/step - accuracy: 0.7706 - loss: 0.4959I've pissed me self in the else statement sir
#    6753/Unknown 1614s 222ms/step - accuracy: 0.7719 - loss: 0.4935I've pissed me self in the else statement sir
#    7202/Unknown 1709s 221ms/step - accuracy: 0.7754 - loss: 0.4870I've pissed me self in the else statement sir
#    7288/Unknown 1727s 221ms/step - accuracy: 0.7761 - loss: 0.4857I've pissed me self in the else statement sir
#    7313/Unknown 1732s 221ms/step - accuracy: 0.7763 - loss: 0.4854I've pissed me self in the else statement sir
#    7376/Unknown 1746s 221ms/step - accuracy: 0.7768 - loss: 0.4845I've pissed me self in the else statement sir
#    7511/Unknown 1774s 221ms/step - accuracy: 0.7778 - loss: 0.4827I've pissed me self in the else statement sir
#    7558/Unknown 1784s 221ms/step - accuracy: 0.7781 - loss: 0.4820I've pissed me self in the else statement sir
#    7876/Unknown 1851s 220ms/step - accuracy: 0.7805 - loss: 0.4777I've pissed me self in the else statement sir
#    8024/Unknown 1881s 220ms/step - accuracy: 0.7815 - loss: 0.4758I've pissed me self in the else statement sir
#    8221/Unknown 1922s 220ms/step - accuracy: 0.7829 - loss: 0.4733I've pissed me self in the else statement sir
#    8397/Unknown 1959s 219ms/step - accuracy: 0.7841 - loss: 0.4711I've pissed me self in the else statement sir
#    8422/Unknown 1964s 219ms/step - accuracy: 0.7842 - loss: 0.4708I've pissed me self in the else statement sir
#    8503/Unknown 1981s 219ms/step - accuracy: 0.7848 - loss: 0.4698I've pissed me self in the else statement sir
#    8602/Unknown 2002s 219ms/step - accuracy: 0.7854 - loss: 0.4686I've pissed me self in the else statement sir
#    8658/Unknown 2014s 219ms/step - accuracy: 0.7858 - loss: 0.4679I've pissed me self in the else statement sir
#    8677/Unknown 2018s 219ms/step - accuracy: 0.7859 - loss: 0.4677I've pissed me self in the else statement sir
#    8726/Unknown 2028s 219ms/step - accuracy: 0.7862 - loss: 0.4671I've pissed me self in the else statement sir
#    8768/Unknown 2037s 219ms/step - accuracy: 0.7865 - loss: 0.4666I've pissed me self in the else statement sir
#    9001/Unknown 2086s 219ms/step - accuracy: 0.7880 - loss: 0.4638I've pissed me self in the else statement sir
#    9168/Unknown 2121s 219ms/step - accuracy: 0.7890 - loss: 0.4619I've pissed me self in the else statement sir
#    9247/Unknown 2138s 218ms/step - accuracy: 0.7895 - loss: 0.4610I've pissed me self in the else statement sir
#    9250/Unknown 2138s 218ms/step - accuracy: 0.7895 - loss: 0.4610I've pissed me self in the else statement sir
#    9262/Unknown 2141s 218ms/step - accuracy: 0.7896 - loss: 0.4608I've pissed me self in the else statement sir
#    9373/Unknown 2164s 218ms/step - accuracy: 0.7903 - loss: 0.4596I've pissed me self in the else statement sir
#    9380/Unknown 2166s 218ms/step - accuracy: 0.7903 - loss: 0.4595I've pissed me self in the else statement sir
#    9448/Unknown 2180s 218ms/step - accuracy: 0.7907 - loss: 0.4588I've pissed me self in the else statement sir
#    9595/Unknown 2211s 218ms/step - accuracy: 0.7916 - loss: 0.4571I've pissed me self in the else statement sir
#    9651/Unknown 2223s 218ms/step - accuracy: 0.7919 - loss: 0.4565
# [mpeg1video @ 0x71855c1e0800] ac-tex damaged at 21 17
# [mpeg1video @ 0x71855c1e0800] Warning MVs not available
# [mpeg1video @ 0x71855c1e0800] ac-tex damaged at 21 17
# [mpeg1video @ 0x71855c1e0800] Warning MVs not available
# [mpeg1video @ 0x71855c1e0800] ac-tex damaged at 21 17
# [mpeg1video @ 0x71855c1e0800] Warning MVs not available
#    9667/Unknown 2226s 218ms/step - accuracy: 0.7920 - loss: 0.4564I've pissed me self in the else statement sir
#    9701/Unknown 2233s 218ms/step - accuracy: 0.7922 - loss: 0.4560I've pissed me self in the else statement sir
#    9952/Unknown 2286s 218ms/step - accuracy: 0.7937 - loss: 0.4533I've pissed me self in the else statement sir
#   10228/Unknown 2344s 218ms/step - accuracy: 0.7952 - loss: 0.4504I've pissed me self in the else statement sir
#   10305/Unknown 2360s 218ms/step - accuracy: 0.7957 - loss: 0.4496I've pissed me self in the else statement sir
#   10523/Unknown 2405s 217ms/step - accuracy: 0.7968 - loss: 0.4474I've pissed me self in the else statement sir
#   10673/Unknown 2437s 217ms/step - accuracy: 0.7976 - loss: 0.4460I've pissed me self in the else statement sir
#   10773/Unknown 2458s 217ms/step - accuracy: 0.7981 - loss: 0.4450I've pissed me self in the else statement sir
#   10794/Unknown 2462s 217ms/step - accuracy: 0.7983 - loss: 0.4448I've pissed me self in the else statement sir
#   10876/Unknown 2480s 217ms/step - accuracy: 0.7987 - loss: 0.4440I've pissed me self in the else statement sir
#   11209/Unknown 2549s 217ms/step - accuracy: 0.8003 - loss: 0.4409I've pissed me self in the else statement sir
#   11479/Unknown 2606s 217ms/step - accuracy: 0.8017 - loss: 0.4384I've pissed me self in the else statement sir
#   11541/Unknown 2619s 217ms/step - accuracy: 0.8020 - loss: 0.4378I've pissed me self in the else statement sir
#   11645/Unknown 2640s 217ms/step - accuracy: 0.8025 - loss: 0.4369I've pissed me self in the else statement sir
#   11659/Unknown 2643s 217ms/step - accuracy: 0.8025 - loss: 0.4367
# [mpeg1video @ 0x718564059f40] ac-tex damaged at 22 17
# [mpeg1video @ 0x718564059f40] Warning MVs not available
#   11783/Unknown 2669s 217ms/step - accuracy: 0.8031 - loss: 0.4356
# [mpeg1video @ 0x7185483cc100] ac-tex damaged at 21 17
# [mpeg1video @ 0x7185483cc100] Warning MVs not available
# [mpeg1video @ 0x7185483cc100] ac-tex damaged at 21 17
# [mpeg1video @ 0x7185483cc100] Warning MVs not available
# [mpeg1video @ 0x7185483cc100] ac-tex damaged at 21 17
# [mpeg1video @ 0x7185483cc100] Warning MVs not available
# [mpeg1video @ 0x7185483cc100] ac-tex damaged at 21 17
# [mpeg1video @ 0x7185483cc100] Warning MVs not available
# [mpeg1video @ 0x7185483cc100] ac-tex damaged at 21 17
# [mpeg1video @ 0x7185483cc100] Warning MVs not available
#   11814/Unknown 2675s 217ms/step - accuracy: 0.8033 - loss: 0.4353I've pissed me self in the else statement sir
#   11890/Unknown 2691s 216ms/step - accuracy: 0.8036 - loss: 0.4347I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
#   11909/Unknown 2695s 216ms/step - accuracy: 0.8037 - loss: 0.4345I've pissed me self in the else statement sir
#   12086/Unknown 2732s 216ms/step - accuracy: 0.8045 - loss: 0.4330I've pissed me self in the else statement sir
#   12137/Unknown 2742s 216ms/step - accuracy: 0.8047 - loss: 0.4325I've pissed me self in the else statement sir
#   12161/Unknown 2747s 216ms/step - accuracy: 0.8048 - loss: 0.4323I've pissed me self in the else statement sir
#   12168/Unknown 2749s 216ms/step - accuracy: 0.8049 - loss: 0.4323I've pissed me self in the else statement sir
#   12181/Unknown 2752s 216ms/step - accuracy: 0.8049 - loss: 0.4322I've pissed me self in the else statement sir
#   12410/Unknown 2800s 216ms/step - accuracy: 0.8060 - loss: 0.4302I've pissed me self in the else statement sir
#   12571/Unknown 2833s 216ms/step - accuracy: 0.8067 - loss: 0.4289I've pissed me self in the else statement sir
#   12657/Unknown 2851s 216ms/step - accuracy: 0.8070 - loss: 0.4282I've pissed me self in the else statement sir
#   12791/Unknown 2879s 216ms/step - accuracy: 0.8076 - loss: 0.4271
# [mpeg1video @ 0x7185400a63c0] ac-tex damaged at 22 17
# [mpeg1video @ 0x7185400a63c0] Warning MVs not available
# [mpeg1video @ 0x7185400a63c0] ac-tex damaged at 22 17
# [mpeg1video @ 0x7185400a63c0] Warning MVs not available
# [mpeg1video @ 0x7185400a63c0] ac-tex damaged at 22 17
# [mpeg1video @ 0x7185400a63c0] Warning MVs not available
# [mpeg1video @ 0x7185400a63c0] ac-tex damaged at 22 17
# [mpeg1video @ 0x7185400a63c0] Warning MVs not available
#   12818/Unknown 2885s 216ms/step - accuracy: 0.8077 - loss: 0.4269I've pissed me self in the else statement sir
#   12913/Unknown 2905s 216ms/step - accuracy: 0.8081 - loss: 0.4261I've pissed me self in the else statement sir
#   12931/Unknown 2908s 216ms/step - accuracy: 0.8082 - loss: 0.4260I've pissed me self in the else statement sir
#   13073/Unknown 2938s 216ms/step - accuracy: 0.8088 - loss: 0.4249I've pissed me self in the else statement sir
#   13360/Unknown 2998s 216ms/step - accuracy: 0.8100 - loss: 0.4226I've pissed me self in the else statement sir
#   13495/Unknown 3027s 216ms/step - accuracy: 0.8105 - loss: 0.4216I've pissed me self in the else statement sir
#   13517/Unknown 3031s 216ms/step - accuracy: 0.8106 - loss: 0.4214I've pissed me self in the else statement sir
#   13631/Unknown 3055s 216ms/step - accuracy: 0.8111 - loss: 0.4206I've pissed me self in the else statement sir
#   13665/Unknown 3062s 216ms/step - accuracy: 0.8112 - loss: 0.4203I've pissed me self in the else statement sir
#   13667/Unknown 3063s 216ms/step - accuracy: 0.8112 - loss: 0.4203I've pissed me self in the else statement sir
#   13769/Unknown 3084s 215ms/step - accuracy: 0.8116 - loss: 0.4195I've pissed me self in the else statement sir
#   14200/Unknown 3175s 215ms/step - accuracy: 0.8133 - loss: 0.4163I've pissed me self in the else statement sir
#   14208/Unknown 3176s 215ms/step - accuracy: 0.8133 - loss: 0.4163I've pissed me self in the else statement sir
#   14238/Unknown 3183s 215ms/step - accuracy: 0.8134 - loss: 0.4161I've pissed me self in the else statement sir
#   14257/Unknown 3187s 215ms/step - accuracy: 0.8135 - loss: 0.4159I've pissed me self in the else statement sir
#   14280/Unknown 3192s 215ms/step - accuracy: 0.8136 - loss: 0.4158I've pissed me self in the else statement sir
#   14369/Unknown 3211s 215ms/step - accuracy: 0.8139 - loss: 0.4151I've pissed me self in the else statement sir
#   14370/Unknown 3211s 215ms/step - accuracy: 0.8139 - loss: 0.4151I've pissed me self in the else statement sir
#   14415/Unknown 3220s 215ms/step - accuracy: 0.8141 - loss: 0.4148I've pissed me self in the else statement sir
#   14537/Unknown 3246s 215ms/step - accuracy: 0.8146 - loss: 0.4139I've pissed me self in the else statement sir
#   14569/Unknown 3253s 215ms/step - accuracy: 0.8147 - loss: 0.4137I've pissed me self in the else statement sir
#   14583/Unknown 3255s 215ms/step - accuracy: 0.8147 - loss: 0.4136I've pissed me self in the else statement sir
#   14651/Unknown 3270s 215ms/step - accuracy: 0.8150 - loss: 0.4131I've pissed me self in the else statement sir
#   14655/Unknown 3271s 215ms/step - accuracy: 0.8150 - loss: 0.4131I've pissed me self in the else statement sir
#   14679/Unknown 3276s 215ms/step - accuracy: 0.8151 - loss: 0.4129I've pissed me self in the else statement sir
#   14725/Unknown 3285s 215ms/step - accuracy: 0.8153 - loss: 0.4126I've pissed me self in the else statement sir
#   14755/Unknown 3292s 215ms/step - accuracy: 0.8154 - loss: 0.4124I've pissed me self in the else statement sir
#   14884/Unknown 3319s 215ms/step - accuracy: 0.8158 - loss: 0.4115I've pissed me self in the else statement sir
#   14889/Unknown 3320s 215ms/step - accuracy: 0.8159 - loss: 0.4115I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
#   14899/Unknown 3322s 215ms/step - accuracy: 0.8159 - loss: 0.4114I've pissed me self in the else statement sir
#   15113/Unknown 3365s 215ms/step - accuracy: 0.8167 - loss: 0.4100I've pissed me self in the else statement sir
#   15167/Unknown 3376s 215ms/step - accuracy: 0.8169 - loss: 0.4096I've pissed me self in the else statement sir
#   15340/Unknown 3410s 215ms/step - accuracy: 0.8175 - loss: 0.4085I've pissed me self in the else statement sir
#   15344/Unknown 3411s 215ms/step - accuracy: 0.8175 - loss: 0.4084
# [mpeg1video @ 0x71852806e100] ac-tex damaged at 22 17
# [mpeg1video @ 0x71852806e100] Warning MVs not available
# [mpeg1video @ 0x71852806e100] ac-tex damaged at 22 17
# [mpeg1video @ 0x71852806e100] Warning MVs not available
# [mpeg1video @ 0x71852806e100] ac-tex damaged at 22 17
# [mpeg1video @ 0x71852806e100] Warning MVs not available
#   15407/Unknown 3424s 215ms/step - accuracy: 0.8177 - loss: 0.4080I've pissed me self in the else statement sir
#   15490/Unknown 3440s 215ms/step - accuracy: 0.8180 - loss: 0.4075I've pissed me self in the else statement sir
#   15715/Unknown 3485s 214ms/step - accuracy: 0.8188 - loss: 0.4060I've pissed me self in the else statement sir
#   15850/Unknown 3512s 214ms/step - accuracy: 0.8192 - loss: 0.4052I've pissed me self in the else statement sir
#   15891/Unknown 3521s 214ms/step - accuracy: 0.8193 - loss: 0.4049I've pissed me self in the else statement sir
#   16019/Unknown 3546s 214ms/step - accuracy: 0.8198 - loss: 0.4041I've pissed me self in the else statement sir
#   16051/Unknown 3553s 214ms/step - accuracy: 0.8199 - loss: 0.4039I've pissed me self in the else statement sir
#   16205/Unknown 3583s 214ms/step - accuracy: 0.8204 - loss: 0.4029I've pissed me self in the else statement sir
#   16419/Unknown 3627s 214ms/step - accuracy: 0.8211 - loss: 0.4016I've pissed me self in the else statement sir
#   16490/Unknown 3641s 214ms/step - accuracy: 0.8213 - loss: 0.4012I've pissed me self in the else statement sir
#   16705/Unknown 3685s 214ms/step - accuracy: 0.8220 - loss: 0.3999I've pissed me self in the else statement sir
#   16766/Unknown 3698s 214ms/step - accuracy: 0.8222 - loss: 0.3995I've pissed me self in the else statement sir
#   16797/Unknown 3705s 214ms/step - accuracy: 0.8223 - loss: 0.3993I've pissed me self in the else statement sir
#   16931/Unknown 3734s 214ms/step - accuracy: 0.8227 - loss: 0.3985I've pissed me self in the else statement sir
#   16932/Unknown 3734s 214ms/step - accuracy: 0.8227 - loss: 0.3985I've pissed me self in the else statement sir
#   17004/Unknown 3749s 214ms/step - accuracy: 0.8229 - loss: 0.3981I've pissed me self in the else statement sir
#   17022/Unknown 3753s 214ms/step - accuracy: 0.8230 - loss: 0.3980I've pissed me self in the else statement sir
#   17040/Unknown 3757s 214ms/step - accuracy: 0.8231 - loss: 0.3979I've pissed me self in the else statement sir
#   17137/Unknown 3777s 214ms/step - accuracy: 0.8234 - loss: 0.3973I've pissed me self in the else statement sir
#   17243/Unknown 3800s 214ms/step - accuracy: 0.8237 - loss: 0.3967I've pissed me self in the else statement sir
#   17298/Unknown 3813s 214ms/step - accuracy: 0.8239 - loss: 0.3964I've pissed me self in the else statement sir
#   17308/Unknown 3815s 214ms/step - accuracy: 0.8239 - loss: 0.3963I've pissed me self in the else statement sir
#   17313/Unknown 3817s 214ms/step - accuracy: 0.8239 - loss: 0.3963I've pissed me self in the else statement sir
#   17342/Unknown 3823s 214ms/step - accuracy: 0.8240 - loss: 0.3961I've pissed me self in the else statement sir
#   17352/Unknown 3825s 214ms/step - accuracy: 0.8240 - loss: 0.3961I've pissed me self in the else statement sir
#   17386/Unknown 3833s 214ms/step - accuracy: 0.8241 - loss: 0.3959I've pissed me self in the else statement sir
#   17463/Unknown 3850s 214ms/step - accuracy: 0.8244 - loss: 0.3954I've pissed me self in the else statement sir
#   17722/Unknown 3910s 214ms/step - accuracy: 0.8251 - loss: 0.3940I've pissed me self in the else statement sir
#   17792/Unknown 3928s 214ms/step - accuracy: 0.8253 - loss: 0.3936I've pissed me self in the else statement sir
#   17814/Unknown 3933s 214ms/step - accuracy: 0.8254 - loss: 0.3935I've pissed me self in the else statement sir
#   17834/Unknown 3938s 214ms/step - accuracy: 0.8255 - loss: 0.3934I've pissed me self in the else statement sir
#   17925/Unknown 3960s 214ms/step - accuracy: 0.8257 - loss: 0.3929I've pissed me self in the else statement sir
#   17926/Unknown 3960s 214ms/step - accuracy: 0.8257 - loss: 0.3929I've pissed me self in the else statement sir
#   17939/Unknown 3964s 214ms/step - accuracy: 0.8258 - loss: 0.3928I've pissed me self in the else statement sir
#   17969/Unknown 3971s 214ms/step - accuracy: 0.8258 - loss: 0.3926I've pissed me self in the else statement sir
#   18152/Unknown 4017s 215ms/step - accuracy: 0.8264 - loss: 0.3916I've pissed me self in the else statement sir
#   18195/Unknown 4028s 215ms/step - accuracy: 0.8265 - loss: 0.3914I've pissed me self in the else statement sir
#   18259/Unknown 4045s 215ms/step - accuracy: 0.8267 - loss: 0.3911I've pissed me self in the else statement sir
#   18263/Unknown 4046s 215ms/step - accuracy: 0.8267 - loss: 0.3911I've pissed me self in the else statement sir
#   18359/Unknown 4071s 215ms/step - accuracy: 0.8270 - loss: 0.3905I've pissed me self in the else statement sir
#   18391/Unknown 4079s 215ms/step - accuracy: 0.8270 - loss: 0.3904I've pissed me self in the else statement sir
#   18397/Unknown 4081s 215ms/step - accuracy: 0.8271 - loss: 0.3903I've pissed me self in the else statement sir
#   18674/Unknown 4152s 216ms/step - accuracy: 0.8278 - loss: 0.3889I've pissed me self in the else statement sir
#   18723/Unknown 4165s 216ms/step - accuracy: 0.8280 - loss: 0.3887I've pissed me self in the else statement sir
#   18780/Unknown 4180s 216ms/step - accuracy: 0.8281 - loss: 0.3884
# [mpeg1video @ 0x717423ef29c0] ignoring SEQ_START_CODE after 101
# [mpeg1video @ 0x717423ef29c0] ignoring GOP_START_CODE after 101
#   18992/Unknown 4234s 217ms/step - accuracy: 0.8287 - loss: 0.3873I've pissed me self in the else statement sir
#   19015/Unknown 4240s 217ms/step - accuracy: 0.8287 - loss: 0.3872I've pissed me self in the else statement sir
#   19028/Unknown 4243s 217ms/step - accuracy: 0.8288 - loss: 0.3871I've pissed me self in the else statement sir
#   19301/Unknown 4315s 217ms/step - accuracy: 0.8295 - loss: 0.3858I've pissed me self in the else statement sir
#   19333/Unknown 4324s 218ms/step - accuracy: 0.8296 - loss: 0.3856I've pissed me self in the else statement sir
#   20138/Unknown 4414s 213ms/step - accuracy: 0.8316 - loss: 0.3817
# 2025-03-14 21:11:30.307247: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2025-03-14 21:11:30.307269: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 	 [[IteratorGetNext/_2]]
# /home/tymstr/.local/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:151: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 2025-03-14 21:11:40.680044: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:9: Filling up shuffle buffer (this may take a while): 10 of 1000
# I've pissed me self in the else statement sir
# [mpeg1video @ 0x71842c010180] ac-tex damaged at 22 17
# [mpeg1video @ 0x71842c010180] Warning MVs not available
# [mpeg1video @ 0x71842c010180] ac-tex damaged at 22 17
# [mpeg1video @ 0x71842c010180] Warning MVs not available
# [mpeg1video @ 0x71842c010180] ac-tex damaged at 22 17
# [mpeg1video @ 0x71842c010180] Warning MVs not available
# 2025-03-14 21:12:00.744489: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:9: Filling up shuffle buffer (this may take a while): 175 of 1000
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# 2025-03-14 21:12:20.754449: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:9: Filling up shuffle buffer (this may take a while): 341 of 1000
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# 2025-03-14 21:12:40.658018: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:9: Filling up shuffle buffer (this may take a while): 504 of 1000
# I've pissed me self in the else statement sir
# 2025-03-14 21:12:50.705822: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:9: Filling up shuffle buffer (this may take a while): 587 of 1000
# I've pissed me self in the else statement sir
# 2025-03-14 21:13:10.635570: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:9: Filling up shuffle buffer (this may take a while): 750 of 1000
# 2025-03-14 21:13:20.735257: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:9: Filling up shuffle buffer (this may take a while): 833 of 1000
# 2025-03-14 21:13:40.684911: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:452] ShuffleDatasetV3:9: Filling up shuffle buffer (this may take a while): 999 of 1000
# 2025-03-14 21:13:40.821608: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:482] Shuffle buffer filled.
# I've pissed me self in the else statement sir
# 2025-03-14 21:13:41.470476: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_159', 8 bytes spill stores, 8 bytes spill loads
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# [mpeg1video @ 0x71844401c200] ignoring SEQ_START_CODE after 101
# [mpeg1video @ 0x71844401c200] ignoring GOP_START_CODE after 101
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# I've pissed me self in the else statement sir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 43
#      38 model4.compile(optimizer='adam',
#      39               loss=tf.keras.losses.BinaryCrossentropy(),  # Change loss function
#      40               metrics=['accuracy'])
#      42 # Model Summary
# ---> 43 model4.fit(train_ds,
#      44           epochs = 9,
#      45           validation_data = val_ds,
#      46           callbacks = tf.keras.callbacks.EarlyStopping(patience = 2, monitor = 'val_loss'))
#
# File ~/.local/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:395, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     384 if getattr(self, "_eval_epoch_iterator", None) is None:
#     385     self._eval_epoch_iterator = TFEpochIterator(
#     386         x=val_x,
#     387         y=val_y,
#    (...)
#     393         shuffle=False,
#     394     )
# --> 395 val_logs = self.evaluate(
#     396     x=val_x,
#     397     y=val_y,
#     398     sample_weight=val_sample_weight,
#     399     batch_size=validation_batch_size or batch_size,
#     400     steps=validation_steps,
#     401     callbacks=callbacks,
#     402     return_dict=True,
#     403     _use_cached_eval_dataset=True,
#     404 )
#     405 val_logs = {
#     406     "val_" + name: val for name, val in val_logs.items()
#     407 }
#     408 epoch_logs.update(val_logs)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:484, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     482 for step, iterator in epoch_iterator:
#     483     callbacks.on_test_batch_begin(step)
# --> 484     logs = self.test_function(iterator)
#     485     callbacks.on_test_batch_end(step, logs)
#     486     if self.stop_evaluating:
#
# File ~/.local/lib/python3.12/site-packages/keras/src/backend/tensorflow/trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File ~/.local/lib/python3.12/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
model4.save_weights('./first_checkpoints.weights.h5')

# %%
import matplotlib.pyplot as plt

def plot_history(history):
    plt.figure(figsize=(12, 5))

    # Loss Plot
    plt.subplot(1, 2, 1)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss', linestyle='dashed')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Loss over Epochs')

    # Accuracy Plot
    plt.subplot(1, 2, 2)
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy', linestyle='dashed')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Accuracy over Epochs')

    plt.show()

# Call the function
plot_history(history)

# %%
def getVideoFiles(S1_DIR: str):
    files = []
    for file in os.listdir(S1_DIR):
        files.append(file)

    return files

def deconstructAlign(dir, filename):
    alignment_array = []
    y = dir + "/" + filename
    with open(y, 'r') as file:
        for line in file:
            alignment_array.append(line.strip('\n').split(" "))
    
    return alignment_array

# %%
import numpy as np
from PIL import Image
import imageio



test_samples = []
example_input = np.random.rand(1, 10, 100, 100, 3).astype(np.float32)
# example_frames = next(iter(test_ds))

single_frame = np.random.rand(100, 100, 3).astype(np.float32)

# Repeat the frame 10 times to create a sequence
video_clip = np.tile(single_frame, (10, 1, 1, 1))  # shape will be (10, 100, 100, 3)

# Now add the batch dimension, resulting in shape (1, 10, 100, 100, 3)
example_input2 = np.expand_dims(video_clip, axis=0)

for i in range(1):
    prediction = model5.predict(example_input2)
    # next(iter(train_ds))
    print(prediction[0][0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 0.99870646

# %% [markdown]
# How does a 3D convNN injest video?
# https://www.tensorflow.org/tutorials/load_data/video
#
# then
#
# https://www.tensorflow.org/tutorials/video/video_classification
#
# then consider
#
# MoviNet for streaming action recognition

# %% [markdown]
# Outputs:
# One neuron with the probalility of the positive class

# %% [markdown]
# Layers:
# - Lookup YOLO ResNet and VGG for processing image and speech data
# -Same number of neurons for all layers should suffice, to increase accuracy consider using a large first layer filtered into smaller layers.(later) More layer > more neurons
# - I’d recommend starting with 1–5 layers and 1–100 neurons and slowly adding more layers and neurons until you start overfitting

# %% [markdown]
# Assessing Layers:
# - You can track your loss and accuracy within your Weights and Biases dashboard to see which hidden layers + hidden neurons combo leads to the best loss
# - Andrej Karpathy also recommends the overfit then regularize approach — “first get a model large enough that it can overfit (i.e. focus on training loss) and then regularize it appropriately (give up some training loss to improve the validation loss).”
# -

# %% [markdown]
# Loss Function:
# - Cross-entropy will serve you well in most cases.

# %% [markdown]
# Batch Size:
# - Smaller may often be better

# %% [markdown]
# Number of epochs:
# - Start with an early number of epochs and use **Early Stopping** to halt training when performance stops improving

# %% [markdown]
# Scaling features:
# - currently scaling based on distance from point on mouth using pixels, consider a scaling relative to the mouth landmarks??

# %% [markdown]
# Learning Rate:
# - To find the best learning rate, start with a very low value (10^-6) and slowly multiply it by a constant until it reaches a very high value (e.g. 10). Measure your model performance (vs the log of your learning rate) in your Weights and Biases dashboard to determine which rate served you well for your problem.
# - The best learning rate is usually half of the learning rate that causes the model to diverge. Feel free to set different values for learn_rate in the accompanying code and seeing how it affects model performance to develop your intuition around learning rates.
# - recommend using the Learning Rate finder method proposed by Leslie Smith.

# %% [markdown]
# Momentum:
# - Gradient descent to consider momentum and local minimas
# - In general, you want your momentum value to be very close to one. 0.9 is a good place to start for smaller datasets

# %% [markdown]
# Vanishing + Exploding Gradients:
# - Activation Functions
#     - User ReLU for now
#     - Revisit if unhappy with networks learning rate
