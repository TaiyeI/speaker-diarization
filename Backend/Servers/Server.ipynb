# %%
# %pip install Flask
# %pip install requests
# %pip install requests-toolbelt
# %pip install opencv-python
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: pip install --upgrade pip
# ...

# %%
from flask import Flask, jsonify, request
from requests_toolbelt.multipart import decoder
import os
import json
import numpy as np
import cv2
import io

# %%
transcriptionservice = Flask(__name__)

# %% [markdown]
# GET METHOD

# %%
@transcriptionservice.route('/', methods=['GET'])
def recieved():
    return jsonify({"respond":"Given"})

# %%
CWD_DIR = os.getcwd()
print(CWD_DIR)
save_path = (CWD_DIR + 'tempfile.mpg')
# Out:
# /home/tymstr/Documents/GitHub/speaker-diarization/Backend/FlaskServer

# %%
@transcriptionservice.route('/', methods=['POST'])
def handle_post():
    try:
        file = request.get_data()
        print("Data:" , file)
        video_stream = io.BytesIO(file)
        temp_filename = "temp_video.mpg"
        with open(temp_filename, "wb") as temp_file:
            temp_file.write(video_stream.getvalue())

        #Run program on tempfile
        #Return ffmpeg captioned video or transcription
        
    except Exception as e:
        print(e)
        print("Failed to process")
    return jsonify({"response":"recieved"})

# %%
transcriptionservice.run(port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [29/Jan/2025 12:47:23] "POST / HTTP/1.1" 200 -
# ...
